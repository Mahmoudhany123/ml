# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
dataset = pd.read_csv("regression.csv")
dataset.shape
dataset.head()


diabetes_x, diabetes_y = datasets.load_diabetes(return_X_y=True)

diabetes_x = diabetes_x[:, np.newaxis, 2]

# split the data into training and testing groups

x_train, x_test, y_train, y_test = train_test_split(
    diabetes_x, diabetes_y, test_size=0.3)
print (x_test)
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(x_train, y_train)

y_pred = regr.predict(x_test)
print("intercept" ,regr.intercept_)
print("Coefficient \n", regr.coef_)
df = pd.DataFrame({"Actual": y_test, "predicted": y_pred})
print(df)
# the mean_squared_error
from sklearn import metrics

print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))


# Plot outputs
dataset.plot(x="block", y="outcome")
plt.scatter(x_test, y_test, color="black")
plt.plot(x_test, y_pred, color="blue", linewidth=3)
plt.xlabel("block")
plt.ylabel("outcome")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# [[ 0.04013997]
#  [ 0.05846277]
#  [-0.06548562]
#  [ 0.03906215]
#  [-0.02129532]
#  [-0.05901875]
#  [-0.06548562]
#  [-0.0374625 ]
#  [-0.04500719]
#  [ 0.03043966]
#  [-0.02884001]
#  [ 0.0347509 ]
#  [-0.06764124]
#  [-0.05578531]
#  [ 0.05522933]
#  [-0.00836158]
#  [-0.02884001]
#  [ 0.00026092]
#  [-0.02991782]
#  [ 0.10480869]
#  [-0.06225218]
#  [-0.04177375]
#  [-0.02345095]
#  [ 0.0250506 ]
#  [ 0.04121778]
#  [-0.04824063]
#  [-0.03422907]
#  [-0.07734155]
#  [-0.07734155]
#  [-0.02021751]
#  [ 0.12852056]
#  [-0.0105172 ]
#  [ 0.04445121]
#  [-0.046085  ]
#  [ 0.01103904]
#  [-0.0191397 ]
#  [ 0.00241654]
#  [-0.02021751]
#  [-0.04824063]
#  [ 0.01858372]
#  [-0.00836158]
#  [ 0.01427248]
#  [-0.00943939]
#  [-0.02452876]
#  [ 0.03582872]
#  [-0.00836158]
#  [-0.046085  ]
#  [-0.06979687]
#  [-0.06117437]
#  [-0.02560657]
#  [ 0.04552903]
#  [-0.00405033]
#  [ 0.07139652]
#  [-0.02560657]
#  [ 0.00457217]
#  [-0.03207344]
#  [ 0.04660684]
#  [-0.06656343]
#  [-0.03315126]
#  [-0.0105172 ]
#  [-0.00836158]
#  [ 0.05415152]
#  [-0.03530688]
#  [-0.04392938]
#  [-0.02345095]
#  [ 0.08540807]
#  [-0.02021751]
#  [ 0.00564998]
#  [-0.05794093]
#  [-0.0374625 ]
#  [ 0.06816308]
#  [ 0.01211685]
#  [ 0.01535029]
#  [-0.04716281]
#  [-0.00728377]
#  [ 0.07139652]
#  [-0.02345095]
#  [ 0.05415152]
#  [ 0.00888341]
#  [ 0.02612841]
#  [ 0.00672779]
#  [ 0.02828403]
#  [ 0.09618619]
#  [ 0.07139652]
#  [-0.0730303 ]
#  [-0.06548562]
#  [ 0.01858372]
#  [ 0.06061839]
#  [-0.08488624]
#  [ 0.06492964]
#  [ 0.05415152]
#  [ 0.00888341]
#  [-0.00297252]
#  [-0.0105172 ]
#  [-0.02021751]
#  [ 0.12313149]
#  [-0.00189471]
#  [-0.06656343]
#  [-0.04931844]
#  [ 0.03690653]
#  [-0.00081689]
#  [ 0.04984027]
#  [ 0.03043966]
#  [-0.01590626]
#  [ 0.02289497]
#  [ 0.02612841]
#  [ 0.08001901]
#  [-0.02129532]
#  [ 0.02181716]
#  [-0.00836158]
#  [ 0.02828403]
#  [-0.0547075 ]
#  [-0.03961813]
#  [-0.00405033]
#  [-0.02452876]
#  [ 0.00133873]
#  [ 0.00133873]
#  [-0.01159501]
#  [-0.00512814]
#  [ 0.03043966]
#  [-0.04069594]
#  [-0.00512814]
#  [ 0.01966154]
#  [-0.03530688]
#  [-0.03099563]
#  [ 0.01535029]
#  [-0.03854032]
#  [-0.05794093]
#  [ 0.05307371]
#  [ 0.03906215]
#  [ 0.01427248]
#  [ 0.09403057]
#  [-0.05794093]]
# intercept 151.32495785680484
# Coefficient
#  [995.57257056]
#      Actual   predicted
# 0     155.0  191.287206
# 1     136.0  209.528888
# 2     153.0   86.129273
# 3      85.0  190.214166
# 4     131.0  130.123918
# ..      ...         ...
# 128   163.0  204.163688
# 129   246.0  190.214166
# 130   297.0  165.534243
# 131   263.0  244.939213
# 132    88.0   93.640554
#
# [133 rows x 2 columns]
# Mean squared error: 3644.33
# Coefficient of determination: 0.27
